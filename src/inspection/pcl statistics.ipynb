# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
my_pcl = np.load("pcl_raw.npy")

# %%
my_pcl.shape
# Out:
# (15545, 4)

# %% [markdown]
# ## statistics on original data

# %%
print("mean:",np.mean(my_pcl[:,0].flatten()))
print("std:",np.std(my_pcl[:,0].flatten()))
_ = plt.hist(my_pcl[:,0].flatten(), bins='auto')
plt.title("X axis")
plt.show()
# Out:
# mean: 13.176729863930056
# std: 13.794733889522464

# %%
print("mean:",np.mean(my_pcl[:,1].flatten()))
print("std:",np.std(my_pcl[:,1].flatten()))

_ = plt.hist(my_pcl[:,1].flatten(), bins='auto')
plt.title("Y axis")
plt.show()
# Out:
# mean: -0.03933465106466758
# std: 8.048778080650045

# %%
print("mean:",np.mean(my_pcl[:,2].flatten()))
print("std:",np.std(my_pcl[:,2].flatten()))
_ = plt.hist(my_pcl[:,2].flatten(), bins='auto')
plt.title("Z axis")
plt.show()
# Out:
# mean: -0.8424225994546248
# std: 2.470688363160738

# %%
_ = plt.hist(my_pcl[:,3].flatten(), bins='auto')
plt.title("Labels")
plt.show()

# %%
r = np.sqrt(my_pcl[:,0]**2 +my_pcl[:,1]**2 +my_pcl[:,2]**2 )
print("mean:",np.mean(my_pcl[:,0].flatten()))
print("std:",np.std(my_pcl[:,0].flatten()))
# Out:
# mean: 13.176729863930056
# std: 13.794733889522464

# %% [markdown]
# ## After transformation statistics

# %%
t_pcl = my_pcl.copy()
t_pcl[:,2] = (t_pcl[:,2]) + 3
# t_pcl =  t_pcl[t_pcl[:,2] >= 0]
print("minumun value after transformation : ",t_pcl[:,2].min())
# Out:
# minumun value after transformation :  0.7281737327575684

# %%
 _ = plt.hist(t_pcl[:,2].flatten(), bins='auto')
plt.title("Z axis")
plt.show()

# %% [markdown]
# ## Kitti

# %%
kitti_pcl = np.load("kitti_sample.npy")
kitti_pcl.shape
# Out:
# (124669,)

# %%
_ = plt.hist(kitti_pcl['x'], bins='auto')
plt.title("X axis")
plt.show()

# %%
_ = plt.hist(kitti_pcl['y'], bins='auto')
plt.title("Y axis")
plt.show()

# %%
_ = plt.hist(kitti_pcl['z'], bins='auto')
plt.title("Z axis")
plt.show()
# Out:
# kitti's min: -11.556541

# %%
arr = np.asarray(kitti_pcl)

# %%
t = np.zeros((arr.shape[0],4))
t[:,0] = arr['x']
t[:,1] = arr['y']
t[:,2] = arr['z']
t[:,3] = arr['intensity']

# %%
np.save("kitti_sample",t)
